# %% [markdown]
# # Data Mining Week 2 Class Practice
# # Rayna Shera Chang / 0706022310022

# %% [markdown]
# # Load the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FuncFormatter

# Download the CSV file from the URL
url = "https://raw.githubusercontent.com/NathaliaMinoque/datasets/refs/heads/main/jabodetabek_house_price.csv"
df = pd.read_csv(url)

df.head()
# Out:
#                                                  url   price_in_rp  \
# 0  https://www.rumah123.com/properti/bekasi/hos11...  2.990000e+09
# 1  https://www.rumah123.com/properti/bekasi/hos10...  1.270000e+09
# 2  https://www.rumah123.com/properti/bekasi/hos10...  1.950000e+09
# 3  https://www.rumah123.com/properti/bekasi/hos10...  3.300000e+09
# 4  https://www.rumah123.com/properti/bekasi/hos10...  4.500000e+09
#
#                                                title  \
# 0  Rumah cantik Sumarecon Bekasi\nLingkungan asri...
# 1          Rumah Kekinian, Magenta Summarecon Bekasi
# 2  Rumah Cantik 2 Lantai Cluster Bluebell Summare...
# 3  Rumah Mewah 2Lantai L10x18 C di Cluster VERNON...
# 4  Rumah Hoek di Cluster Maple Summarecon Bekasi,...
#
#                      address           district     city       lat  \
# 0  Summarecon Bekasi, Bekasi  Summarecon Bekasi   Bekasi -6.223945
# 1  Summarecon Bekasi, Bekasi  Summarecon Bekasi   Bekasi -6.223945
# ...

# %% [markdown]
# # Inspect the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3553 entries, 0 to 3552
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   url                   3553 non-null   object
#  1   price_in_rp           3553 non-null   float64
#  2   title                 3553 non-null   object
#  3   address               3553 non-null   object
#  4   district              3553 non-null   object
#  5   city                  3553 non-null   object
#  6   lat                   3553 non-null   float64
#  7   long                  3553 non-null   float64
#  8   facilities            3553 non-null   object
#  9   property_type         3552 non-null   object
#  10  ads_id                3549 non-null   object
#  11  bedrooms              3519 non-null   float64
#  12  bathrooms             3524 non-null   float64
#  13  land_size_m2          3551 non-null   float64
# ...

# %%
df.describe()
# Out:
#         price_in_rp          lat         long     bedrooms    bathrooms  \
# count  3.553000e+03  3553.000000  3553.000000  3519.000000  3524.000000
# mean   4.191685e+09    -6.324721   106.792881     3.326513     2.624858
# std    1.375067e+10     0.129245     0.172159     2.672148     2.696497
# min    4.200000e+07    -6.894828   106.402315     1.000000     1.000000
# 25%    8.000000e+08    -6.397933   106.687295     2.000000     2.000000
# 50%    1.500000e+09    -6.300733   106.799954     3.000000     2.000000
# 75%    3.590000e+09    -6.231754   106.874766     4.000000     3.000000
# max    5.800000e+11    -6.102478   109.771691    99.000000    99.000000
#
#        land_size_m2  building_size_m2     carports  maid_bedrooms  \
# count   3551.000000       3551.000000  3553.000000    3553.000000
# mean     204.806815        186.587440     1.197861       0.496482
# std      402.127746        248.443471     1.114996       0.685723
# ...

# %% [markdown]
# >> **Key findings**:
# 1. The url column only contains ad links, so it is not relevant for analysis and was dropped.
# 2. The price_in_rp column has extreme values, with a minimum of Rp42 million and a maximum of Rp580 billion, showing outliers far above the normal market.
# 3. The bedrooms column normally ranges from 1 to 10, but there is an outlier with 99 rooms, likely from a boarding house or apartment.
# 4. The bathrooms column also has an outlier with 99 bathrooms.
# 5. The land_area column ranges from 12 m² to 8000 m², which includes very large outliers, and the same applies to the building_area column.
# 6. The garages column usually has 1 garage, but there is an outlier with 50 garages.
# 7. The floors column ranges from 1 to 5 floors, which is still normal.
# 8. The building_age column has many missing values and even includes an entry of 152 years.
# 9. The year_built column shows an error because the maximum value is 2052, while the current year is only 2025.
# 10. The building_orientation column is missing in more than half of the data, so it can be dropped.
# 11. The facilities column is always filled but in long text form, so it needs to be processed, for example by counting the number of facilities.
# 12. Some categorical columns such as certificate, property_condition, furnishing, and building_orientation need label normalization.
# 13. The title column only contains ad titles and does not give important information, so it can be dropped.
# 14. The ads_id column only works as a unique identifier and does not contribute to analysis, so it can be dropped.
# 15. The garages column again shows a maximum of 50 garages, which is likely a luxury or commercial property.

# %%
# Calculate null values and percentage
null_counts = df.isnull().sum()
null_percentages = (null_counts / len(df)) * 100

# Create a DataFrame for columns with null values
null_df = pd.DataFrame({'Null Count': null_counts, 'Null Percentage': null_percentages})

# Filter for columns with null values
null_df = null_df[null_df['Null Count'] > 0]


# Format the percentage with two decimal places and % symbol
null_df['Null Percentage'] = null_df['Null Percentage'].map('{:.2f}%'.format)


null_df
# Out:
#                       Null Count Null Percentage
# property_type                  1           0.03%
# ads_id                         4           0.11%
# bedrooms                      34           0.96%
# bathrooms                     29           0.82%
# land_size_m2                   2           0.06%
# building_size_m2               2           0.06%
# certificate                  141           3.97%
# floors                         6           0.17%
# building_age                1445          40.67%
# year_built                  1445          40.67%
# property_condition           246           6.92%
# building_orientation        1647          46.36%
# furnishing                   387          10.89%

# %% [markdown]
# >> From the missing value summary, we can see that building_age (40.67%) and building_orientation (46.36%) have very high null percentages, making them less reliable for analysis unless carefully imputed. Meanwhile, furnishing (10.89%) and property_condition (6.92%) also show notable missing values but are still manageable with imputations. Most other columns have very minimal missing data (<4%), meaning the dataset is generally complete and suitable for preprocessing.

# %%
# Create the horizontal bar plot
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
sns.barplot(x='Null Count', y=null_df.index, data=null_df, orient='h', palette='rainbow')
plt.xlabel('Number of Null Values', fontsize=12)
plt.ylabel('Columns', fontsize=12)
plt.title('Null Values per Column', fontsize=14)

# Add labels to the bars
for i, v in enumerate(null_df['Null Count']):
    plt.text(v + 1, i, str(v), color='black', va='center', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-4184322526.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Null Count', y=null_df.index, data=null_df, orient='h', palette='rainbow')

# %% [markdown]
# # Unique Values

# %%
# Display unique values for each column
for col in df.columns:
  print(f"Unique values for column '{col}':")
  print(df[col].unique())
  print("-" * 20)
# Out:
# Unique values for column 'url':
# ['https://www.rumah123.com/properti/bekasi/hos11360272/#qid~213b5619-a399-47b3-bfcf-faaef6b542d5'
#  'https://www.rumah123.com/properti/bekasi/hos10680347/#qid~748f5d2d-8d3a-4a4e-a1b4-37c7be7ffc25'
#  'https://www.rumah123.com/properti/bekasi/hos10685867/#qid~f6c2cf9d-44fa-4c1a-8749-8ee96b116e93'
#  ...
#  'https://www.rumah123.com/properti/tangerang/hos11359594/#qid~0d9492e8-7326-465d-85ee-e54559fedc26'
#  'https://www.rumah123.com/properti/tangerang/hos11359313/#qid~5d5b05f9-ab0d-4774-ae61-bddd6e38b7f0'
#  'https://www.rumah123.com/properti/tangerang/hos11358964/#qid~5d5b05f9-ab0d-4774-ae61-bddd6e38b7f0']
# --------------------
# Unique values for column 'price_in_rp':
# [2.99e+09 1.27e+09 1.95e+09 3.30e+09 4.50e+09 2.70e+09 2.35e+09 2.90e+09
#  2.55e+09 9.52e+08 1.80e+09 2.50e+09 5.36e+09 2.25e+09 2.45e+09 1.25e+08
#  1.98e+09 7.64e+08 2.00e+09 4.80e+08 1.90e+09 3.00e+08 5.27e+09 2.80e+09
# ...

# %% [markdown]
# # Drop Unused Column

# %%
# Drop column  url, title, and ads_id
df = df.drop(['url', 'title', 'ads_id', 'property_type','address', 'lat', 'long', 'district'], axis=1)
df.head()

# Explanation
# 'url' Contains only the advertisement link, does not provide information for data analysis or predictive modeling → dropped.
# 'title' Only the advertisement title (usually promotional sentences), does not contain quantifiable analytical value → dropped.
# 'ads_id' Contains unique advertisement ID, useful only as an identifier, has no meaning in price analysis → dropped.
# 'property_type' Almost all values are the same (majority "Rumah"), this variable does not provide informative variation → dropped.
# 'address' Contains long text address, unstructured, difficult to use directly for quantitative analysis. Location information is already covered in district and city → dropped.
# 'lat & long' Although coordinates can be useful, city are sufficient to represent location. Without spatial analysis/geo-mapping, these columns can be dropped to simplify the dataset → dropped.
# 'district' Regional information is already sufficiently represented by the city column, making this column redundant and adding no analytical value → dropped.
# Out:
#     price_in_rp     city                                         facilities  \
# 0  2.990000e+09   Bekasi       Tempat Jemuran, Jalur Telepon, Taman,  Taman
# 1  1.270000e+09   Bekasi                                              Taman
# 2  1.950000e+09   Bekasi   Jogging Track,  Kolam Renang, Masjid,  Taman,...
# 3  3.300000e+09   Bekasi   Jalur Telepon,  Jogging Track, Track Lari,  K...
# 4  4.500000e+09   Bekasi   Jogging Track,  Kolam Renang, Taman, Jalur Te...
#
#    bedrooms  bathrooms  land_size_m2  building_size_m2  carports  \
# 0       4.0        4.0         239.0             272.0       0.0
# 1       3.0        2.0          55.0              69.0       1.0
# 2       3.0        3.0         119.0             131.0       1.0
# 3       3.0        3.0         180.0             174.0       0.0
# 4       4.0        3.0         328.0             196.0       2.0
#
#                   certificate electricity  maid_bedrooms  maid_bathrooms  \
# ...

# %% [markdown]
# # Histogram for Numerical Columns

# %%
# Select only related numerical columns for histogram
selected_cols = ['bedrooms', 'bathrooms', 'land_size_m2', 'building_size_m2', 'floors', 'building_age']

# Create histograms for each numerical column
for col in selected_cols:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col].dropna(), kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# >> **Insight**: This histogram visualization is used to observe the distribution of numerical features such as bedrooms, bathrooms, land size, building size, floors, and building age. By plotting the frequency of values, we can see whether the data is normally distributed (symmetrical) or skewed (right-skewed or left-skewed). From the plots above, most features like bedrooms, bathrooms, land_size_m2, and building_size_m2 are right-skewed, meaning the majority of houses are clustered at lower values (e.g., 2–3 bedrooms, 2 bathrooms, land/building size around 100–200 m²) while a few outliers extend to very high values (dozens of rooms or thousands of m²). The floors variable shows a discrete distribution where most houses have 1–2 floors, while building_age is also right-skewed with most houses being newly built (0–5 years) and a few very old properties.
#
# >>The insight is that because the data is skewed to the right, median imputation is often a better strategy than mean when filling missing values, since the mean would be biased by extreme outliers. This understanding also helps in modeling: some features may need log transformation to reduce skewness and better fit statistical or machine learning models.

# %% [markdown]
# # Handle missing values

# %% [markdown]
# Fill Missing Values with median

# %%
# Fill missing values in 'bedrooms' with the median
median_bedrooms = df['bedrooms'].median()
df['bedrooms'] = df['bedrooms'].fillna(median_bedrooms)

# Fill missing values in 'bathrooms' with the median
median_bathrooms = df['bathrooms'].median()
df['bathrooms'] = df['bathrooms'].fillna(median_bathrooms)

# Fill missing values in 'land_size_m2' with the median
median_land_size_m2 = df['land_size_m2'].median()
df['land_size_m2'] = df['land_size_m2'].fillna(median_land_size_m2)

# Fill missing values in 'building_size_m2' with the median
median_building_size_m2 = df['building_size_m2'].median()
df['building_size_m2'] = df['building_size_m2'].fillna(median_building_size_m2)

# Fill missing values in 'floors' with the median
median_floors = df['floors'].median()
df['floors'] = df['floors'].fillna(median_floors)

# %% [markdown]
# >> This code is used to handle missing values in numerical columns by filling them with the median of each column. The choice of median instead of mean is important because, as shown in the histograms earlier, many of these variables (bedrooms, bathrooms, land_size_m2, building_size_m2) are right-skewed with extreme outliers. Using the mean would pull the imputation toward unusually high values, while the median is more robust and better represents the “typical” property. This approach helps maintain data quality by ensuring no missing values remain, while also reducing the impact of outliers.

# %%
# Fill missing values in categorical columns with 'Unknown'
df['property_condition'] = df['property_condition'].fillna('Unknown')
df['building_orientation'] = df['building_orientation'].fillna('Unknown')
df['furnishing'] = df['furnishing'].fillna('Unknown')

# %% [markdown]
# >> This code is used to handle missing values in categorical columns by replacing them with the placeholder "Unknown". Unlike numeric data, categorical variables (such as property_condition, building_orientation, and furnishing) cannot be imputed with mean or median, since they represent labels rather than quantities. By filling missing values with "Unknown", we preserve all rows in the dataset without introducing bias toward the most frequent category (mode imputation).

# %%
# Standardization for column certificate
if 'certificate' in df.columns:
    df['certificate'] = df['certificate'].astype(str).str.lower().str.strip()

    def map_cert(x):
        if 'shm' in x or 'sertifikat hak milik' in x:
            return 'SHM'
        elif 'hgb' in x or 'hak guna bangunan' in x:
            return 'HGB'
        elif 'hp' in x or 'hak pakai' in x:
            return 'HP'
        else:
            return 'Lainnya'

    df['certificate'] = df['certificate'].apply(map_cert)

# Preview the results
print(df['certificate'].unique())
# Out:
# ['SHM' 'HGB' 'Lainnya' 'HP']

# %% [markdown]
# >> This code is used to standardize the values in the certificate column so they are consistent and easier to analyze. The raw data may contain variations in text format, such as "shm - sertifikat hak milik", "hgb - hak guna bangunan", or "hp - hak pakai". By converting everything to lowercase, trimming spaces, and then mapping them into standardized categories (SHM, HGB, HP, Lainnya), we reduce noise and avoid duplication caused by inconsistent labeling.

# %%
# Count the occurrences of each certificate type
certificate_counts = df['certificate'].value_counts()

# Create the pie chart
plt.figure(figsize=(5, 5))
plt.pie(certificate_counts, labels=certificate_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Proportion of Certificate Types', fontsize=14)
plt.axis('equal')
plt.show()

# %% [markdown]
# >> **Insight**: This pie chart shows the proportion of certificate types among the listed properties. The majority of houses, about 84.5%, have `SHM (Sertifikat Hak Milik)`, which represents the strongest form of property ownership in Indonesia. Meanwhile, `HGB (Hak Guna Bangunan)` makes up 5.9%, and `Lainnya (other certificates such as PPJB, girik, adat)` account for 9.6%. Interestingly, `HP (Hak Pakai)` is almost negligible at 0%, indicating it is rarely used for residential properties. The insight is that most property transactions in this dataset are backed by `SHM`, suggesting buyers and sellers prioritize legal certainty and strong ownership rights. The smaller share of `HGB` and `Lainnya` may indicate niche cases such as commercial buildings, apartments, or transitional land rights, while the absence of HP confirms it is not a popular option in this housing market.

# %%
# Overwrite facilities with facility level (0–3)
if 'facilities' in df.columns:
    def facility_level(s):
        if pd.isna(s) or s.strip() == "":
            return 0
        # Split by comma, remove duplicates, count
        count = len(set([f.strip().lower() for f in s.split(',') if f.strip() != ""]))
        if count == 0:
            return 0
        elif count <= 3:
            return 1
        elif count <= 6:
            return 2
        else:
            return 3

    df['facilities'] = df['facilities'].apply(facility_level)

# Preview result
print(df['facilities'].unique())
# Out:
# [1 2 3]

# %% [markdown]
# >> This code is used to simplify and standardize the facilities column by converting a long list of textual facility descriptions into a numeric scale (0–3). Instead of storing every facility name, the function counts how many unique facilities each property has, then assigns it to a level: 0 = no facilities, 1 = few (1–3), 2 = medium (4–6), and 3 = many (7 or more). The insight is that this transformation makes the feature much easier to analyze and use in models. For example, instead of handling dozens of possible facility strings, we now have a clear categorical variable that indicates the overall amenity level of a property.

# %%
# Count the occurrences of each facility level
facility_counts = df['facilities'].value_counts().sort_index()

# Create the bar plot for facilities
plt.figure(figsize=(8, 6))
sns.barplot(
    x=facility_counts.index,
    y=facility_counts.values,
    hue=facility_counts.index,
    palette='viridis',
    legend=False
)
plt.xlabel('Facility Level', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Distribution of Facility Levels', fontsize=14)

# Add labels to the bars
for i, v in enumerate(facility_counts.values):
    plt.text(i, v + 10, str(v), ha='center', fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# >> **Insight**: This bar plot shows the distribution of facility levels across properties. Most properties fall into `level 1 (few facilities)` with 1,349 listings, followed closely by `level 3 (many facilities)` with 1,235 listings, while `level 2 (medium facilities)` has the lowest count at 969. The insight is that the market is polarized: properties are often listed with either very few facilities or a large number of them, while moderate facility offerings are less common. This suggests that developers and sellers tend to differentiate their properties as either basic/affordable or premium/complete, with fewer options in the mid-range segment.

# %%
# Define Rupiah formatter (billions)
def rupiah_bil(x, pos):
    return f'Rp {x*1e-9:,.0f}B'  # divides by 1e9 and adds B for billion

# Boxplot of Price vs Facility Level
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['facilities'], y=df['price_in_rp'])
plt.yscale('log')
plt.gca().yaxis.set_major_formatter(FuncFormatter(rupiah_bil))
plt.xlabel('Facility Level (0=None, 3=Many)', fontsize=12)
plt.ylabel('Price (Rp, log scale)', fontsize=12)
plt.title('Property Prices by Facility Level', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# >> **Insight**: This box plot illustrates the relationship between facility levels (1–3) and property prices (log scale, in Rupiah). The distribution shows that properties with higher facility levels (2 and 3) tend to have slightly higher median prices compared to those with fewer facilities (level 1). However, the spread of prices is very wide across all facility levels, with significant outliers reaching into the tens and even hundreds of billions of Rupiah. This means that while having more facilities generally correlates with higher property prices, the effect is not strongly pronounced, as prices overlap heavily across categories. This suggests that other factors such as location, land size, or building size likely play a more dominant role in determining property value than facilities alone.

# %%
# Make sure the column is numeric
df['year_built'] = pd.to_numeric(df['year_built'], errors='coerce')

# Fill missing values in 'year_built' with the median
median_year_built = df['year_built'].median()
df['year_built'] = df['year_built'].fillna(median_year_built)

# Calculate building_age only for rows where it's NaN
df['building_age'] = np.where(
    df['building_age'].isna(),
    2025 - df['year_built'],
    df['building_age']
)

# Preview the results
print(df[['year_built','building_age']].head())
# Out:
#    year_built  building_age
# 0      2017.0           5.0
# 1      2021.0           4.0
# 2      2021.0           4.0
# 3      2016.0           6.0
# 4      2013.0           9.0

# %% [markdown]
# >> This code cleans and completes the year_built and building_age columns to ensure consistency. The year_built column is converted to numeric, with invalid values coerced to NaN, and missing values are filled using the median instead of the mean, since the data distribution is uneven and the median is less sensitive to outliers. This avoids skewing the imputation toward unrealistic values. Then, building_age is calculated as 2025 - year_built only for rows where it was missing, ensuring both columns stay aligned without overwriting existing valid data.

# %% [markdown]
# # Feature Engineering: Binning

# %%
# Define bins and labels
bins = [0, 5, 10, 15, 20, 25, df['building_age'].max()]
labels = ['0-5 years', '6-10 years', '11-15 years','16-20 years', '21-25 years', '>25 years']

df['building_age'] = pd.cut(df['building_age'], bins=bins, labels=labels, include_lowest=True)

# Preview
print(df[['building_age']])
# Out:
#      building_age
# 0       0-5 years
# 1       0-5 years
# 2       0-5 years
# 3      6-10 years
# 4      6-10 years
# ...           ...
# 3548    0-5 years
# 3549    0-5 years
# 3550    0-5 years
# 3551    0-5 years
# 3552    0-5 years
#
# [3553 rows x 1 columns]

# %% [markdown]
# >> This code applies feature engineering through binning on the building_age column by grouping continuous numeric values into categorical ranges. The bins are defined in intervals (0–5, 6–10, 11–15, 16–20, 21–25, and greater than 25 years), and each range is assigned a descriptive label. The pd.cut() function is used to transform the raw age values into these categories, making the data easier to interpret and analyze. This approach is useful because it simplifies skewed numerical data, highlights patterns across age groups, and allows comparisons such as whether newer properties (0–5 years) tend to be priced higher than older ones (>25 years). In short, binning converts raw numbers into meaningful segments that are more useful for visualization and modeling.

# %%
# Count the occurrences of each building age category
building_age_counts = df['building_age'].value_counts().sort_index()

# Create the bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=building_age_counts.index, y=building_age_counts.values, palette='viridis')
plt.xlabel('Building Age Category', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Distribution of Building Age Categories', fontsize=14)

# Add labels to the bars
for i, v in enumerate(building_age_counts.values):
    plt.text(i, v + 10, str(v), ha='center', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1453845968.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=building_age_counts.index, y=building_age_counts.values, palette='viridis')

# %% [markdown]
# >> **Insight**: This bar chart shows the distribution of properties by building age categories. The vast majority of properties, over 3,000 units, fall into the 0–5 years category, indicating that most listings in the dataset are relatively new constructions. The number of properties decreases drastically as the building age increases, with only a small fraction older than 10 years and very few exceeding 25 years. This means that the housing market represented in this dataset is heavily dominated by new and recently built properties. This could reflect ongoing urban development and a strong demand for modern housing. For buyers, this means they are more likely to encounter newer houses, while older properties may be scarce or considered less attractive.

# %% [markdown]
# # Feature Engineering: Mapping

# %%
# Normalize to lowercase strings while preserving NaN
df['property_condition'] = df['property_condition'].astype('string').str.lower().str.strip()
df['furnishing'] = df['furnishing'].astype('string').str.lower().str.strip()

# Define furniture set
furniture_set = {'semi furnished', 'unfurnished', 'furnished'}

# Handle furnishing NaN
df.loc[df['furnishing'].isna() & df['property_condition'].isin(furniture_set),
       'furnishing'] = df['property_condition']

df.loc[df['furnishing'].isna() & ~df['property_condition'].isin(furniture_set),
       'furnishing'] = 'unknown'

# Replace 'baru' in furnishing with 'unknown'
df['furnishing'] = df['furnishing'].replace({'baru': 'unknown'})

# Replace misplaced furnishing values in property_condition
df['property_condition'] = df['property_condition'].replace({
    'unfurnished': 'unknown',
    'semi furnished': 'unknown',
    'furnished': 'unknown'
})

# Handle property_condition NaN
df.loc[df['property_condition'].isna() & (df['furnishing'] == 'baru'),
       'property_condition'] = 'baru'

df.loc[df['property_condition'].isna() & df['furnishing'].isin(furniture_set),
       'property_condition'] = 'unknown'

print(df['property_condition'].value_counts())
print(df['furnishing'].value_counts())
# Out:
# property_condition
# bagus             1437
# baru              1328
# unknown            275
# bagus sekali       261
# sudah renovasi     158
# butuh renovasi      94
# Name: count, dtype: Int64
# furnishing
# unfurnished       2066
# semi furnished     833
# unknown            416
# furnished          238
# Name: count, dtype: Int64

# %% [markdown]
# >> This code is designed to clean and standardize the property_condition and furnishing columns by resolving inconsistencies and handling missing values. Since some values such as unfurnished, semi furnished, and furnished appeared incorrectly in property_condition, they are reassigned to unknown to avoid overlap with the furnishing column. Missing values in furnishing are filled using related information from property_condition when possible, otherwise replaced with unknown. Additionally, baru entries in furnishing are corrected to unknown because they describe condition rather than furnishing. This cleaning process ensures that both columns represent their intended meaning clearly, property_condition focuses strictly on the state of the building (baru, bagus, renovasi, dll.), while furnishing consistently describes interior equipment (unfurnished, semi furnished, furnished).

# %%
# Map values to scores
pc_map = {
    'baru': 3, 'bagus': 1, 'bagus sekali': 2,
    'sudah renovasi': 2, 'butuh renovasi': 0, 'unknown': 0
}
fz_map = {
    'unfurnished': 0, 'semi furnished': 1, 'furnished': 2, 'unknown': 0
}

# Create the combined score in a new column
df['condition_furnishing_score'] = (
    df['property_condition'].map(pc_map).fillna(0).astype(int) +
    df['furnishing'].map(fz_map).fillna(0).astype(int)
)

# Quick check
print(df[['property_condition', 'furnishing', 'condition_furnishing_score']].head())

print(df['condition_furnishing_score'].value_counts())
# Out:
#   property_condition   furnishing  condition_furnishing_score
# 0              bagus  unfurnished                           1
# 1              bagus      unknown                           1
# 2              bagus  unfurnished                           1
# 3       bagus sekali  unfurnished                           2
# 4              bagus  unfurnished                           1
# condition_furnishing_score
# 3    1247
# 1    1052
# 2     489
# 4     363
# 0     333
# 5      69
# Name: count, dtype: int64

# %% [markdown]
# >> This code performs feature engineering using mapping to convert categorical values from `property_condition` and `furnishing` into numeric scores, then combines them into a single column for easier analysis. Two dictionaries (pc_map and fz_map) are defined to map each category to a score that reflects its relative quality—for example, baru is mapped to 3 (highest condition), bagus sekali and sudah renovasi to 2, while butuh renovasi and unknown get 0. Similarly, in furnishing, furnished is mapped to 2, semi furnished to 1, and both unfurnished and unknown to 0. These mapped values are then summed into a new feature called `condition_furnishing_score`, which represents the overall housing quality score by combining both the building’s physical condition and its furnishing status. This mapping transforms subjective categorical data into a structured numeric variable, making it easier to use in statistical analysis and machine learning models. It also provides a consolidated measure of property quality, where higher scores indicate better condition and more complete furnishing, which can be directly compared against property prices to analyze whether higher-quality homes yield higher market values.

# %%
# Drop property_condition and furnishing columns
df = df.drop(columns=['property_condition', 'furnishing'], errors='ignore')

# %% [markdown]
# >> This code removes the property_condition and furnishing columns from the dataframe because their information has already been combined into the new feature condition_furnishing_score, making the original columns redundant.

# %% [markdown]
# # Pie Chart

# %%
# Count the occurrences of each score
score_counts = df['condition_furnishing_score'].value_counts()

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(score_counts, labels=score_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Condition and Furnishing Scores', fontsize=14)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# >> **Insight**: This pie chart shows the distribution of combined condition and furnishing scores for the properties. The largest share belongs to score 3 (35.1%), followed by score 1 (29.6%), meaning most houses are either in good condition or minimally furnished. Scores 2 (13.8%) and 4 (10.2%) make up smaller portions, while 0 (9.4%) represents properties with poor or unknown condition and no furnishing, and only 1.9% of properties achieve the highest score of 5. The insight is that most properties fall in the mid-range quality category rather than the extremes. Very few homes are at the highest quality level, suggesting that fully renovated and fully furnished houses are rare in this dataset. Conversely, a significant portion of low scores (0 and 1) shows that many properties still need renovation or lack proper furnishing, which could indicate opportunities for improvement or investment.

# %% [markdown]
# # Bar Chart Visualization

# %%
# Count the occurrences of each city
city_counts = df['city'].value_counts()

# Create the bar plot for city
plt.figure(figsize=(12, 6))
sns.barplot(
    x=city_counts.index,
    y=city_counts.values,
    hue=city_counts.index,
    palette='viridis',
    legend=False
)
plt.xlabel('City', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Distribution of Properties by City', fontsize=14)
plt.xticks(rotation=45, ha='right')

# Add labels to the bars
for i, v in enumerate(city_counts.values):
    plt.text(i, v + 10, str(v), ha='center', fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# >> **Insight**: This bar chart shows the distribution of properties by city in the Jabodetabek area. The majority of listings are concentrated in Bogor (881 properties) and Tangerang (851 properties), followed by Bekasi (586) and Depok (526). In contrast, property counts are much lower in Jakarta, with Jakarta Selatan (240) leading among the Jakarta regions, while Jakarta Pusat (38) has the fewest listings. The insight is that the housing market supply is significantly larger in the suburban areas (Bogor, Tangerang, Bekasi, Depok) compared to Jakarta’s inner regions. This suggests that suburban cities are more active in property development, possibly due to larger available land and relatively more affordable housing, whereas central Jakarta has limited supply, likely driven by high land prices and limited space. This distribution highlights where buyers are most likely to find available housing options and where developers are focusing new projects.

# %% [markdown]
# # Box Plot Distribution

# %%
# Create a box plot for land_size_m2
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['land_size_m2'])
plt.xlabel('Land Size (m2)')
plt.title('Distribution of Land Size')
plt.tight_layout()
plt.show()

# Create a box plot for building_size_m2
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['building_size_m2'])
plt.xlabel('Building Size (m2)')
plt.title('Distribution of Building Size')
plt.tight_layout()
plt.show()

# Create a box plot for price_in_rp
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['price_in_rp'])
plt.xlabel('Price (Rp)')
plt.title('Distribution of Price')
plt.tight_layout()
plt.show()

# Create a box plot for Jumlah Kamar
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bedrooms'])
plt.xlabel('Total of Bedrooms')
plt.title('Distribution of Bedrooms')
plt.tight_layout()
plt.show()

# Create a box plot for Jumlah Kamar Mandi
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bathrooms'])
plt.xlabel('Total of Bathrooms')
plt.title('Distribution of Bathrooms')
plt.tight_layout()
plt.show()

# %% [markdown]
# >> **Insight**:
# >>1. Land Size (m2):
# The majority of land sizes cluster at the lower end, with the box (IQR) showing most properties under ~500 m². However, there are many extreme outliers extending beyond 8,000 m², showing that while typical homes have small-to-medium plots, a few very large properties skew the distribution.
# 2. Building Size (m2):
# Most building sizes are compact, centered below ~400 m², but there are several extreme outliers reaching up to 6,000 m². This indicates that while the majority of houses are relatively modest in size, some luxury or commercial-type properties with very large building areas exist in the dataset.
# 3. Price (Rp):
# Property prices are highly skewed with most houses priced below a few billion Rupiah, but extreme outliers go up to Rp 580 billion. This wide spread suggests strong variability in the market, where a small number of premium properties push the maximum values far beyond the median.
# 4. Bedrooms:
# Most houses have between 2–5 bedrooms, but there are extreme cases with more than 50, even up to 99 bedrooms, likely representing boarding houses, hotels, or data entry errors. This explains why the whiskers are small compared to the large spread of outliers.
# 5. Bathrooms:
# The typical range is 2–4 bathrooms, but outliers include houses with dozens, even up to 99 bathrooms. Similar to bedrooms, these are likely commercial buildings, boarding houses, or data anomalies.
#
# Overall, all features show strong right-skewness with heavy outliers. This suggests that most properties are within a normal residential scale, but a small fraction of extremely large, luxurious, or commercial-type properties create long tails.

# %%
# Keep only Price <= 1.2e11 Rupiah
df = df[df['price_in_rp'] <= 1.2e11]

# Create a box plot for land_size_m2
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['land_size_m2'])
plt.xlabel('Land Size (m2)')
plt.title('Distribution of Land Size')
plt.tight_layout()
plt.show()

# Create a box plot for building_size_m2
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['building_size_m2'])
plt.xlabel('Building Size (m2)')
plt.title('Distribution of Building Size')
plt.tight_layout()
plt.show()

# Create a box plot for price_in_rp
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['price_in_rp'])
plt.xlabel('Price (Rp)')
plt.title('Distribution of Price')
plt.tight_layout()
plt.show()

# Create a box plot for Jumlah Kamar
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bedrooms'])
plt.xlabel('Total of Bedrooms')
plt.title('Distribution of Bedrooms')
plt.tight_layout()
plt.show()

# Create a box plot for Jumlah Kamar Mandi
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bathrooms'])
plt.xlabel('Total of Bathrooms')
plt.title('Distribution of Bathrooms')
plt.tight_layout()
plt.show()

# %%
# Keep only Land Size <= 3000
df = df[df['land_size_m2'] <= 3000]

# Create a box plot for land_size_m2
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['land_size_m2'])
plt.xlabel('Land Size (m2)')
plt.title('Distribution of Land Size')
plt.tight_layout()
plt.show()

# Create a box plot for building_size_m2
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['building_size_m2'])
plt.xlabel('Building Size (m2)')
plt.title('Distribution of Building Size')
plt.tight_layout()
plt.show()

# Create a box plot for price_in_rp
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['price_in_rp'])
plt.xlabel('Price (Rp)')
plt.title('Distribution of Price')
plt.tight_layout()
plt.show()

# Create a box plot for Jumlah Kamar
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bedrooms'])
plt.xlabel('Total of Bedrooms')
plt.title('Distribution of Bedrooms')
plt.tight_layout()
plt.show()

# Create a box plot for Jumlah Kamar Mandi
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bathrooms'])
plt.xlabel('Total of Bathrooms')
plt.title('Distribution of Bathrooms')
plt.tight_layout()
plt.show()

# %%
# Keep only Building Size <= 1600
df = df[df['building_size_m2'] <= 1600]

# Create a box plot for land_size_m2
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['land_size_m2'])
plt.xlabel('Land Size (m2)')
plt.title('Distribution of Land Size')
plt.tight_layout()
plt.show()

# Create a box plot for building_size_m2
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['building_size_m2'])
plt.xlabel('Building Size (m2)')
plt.title('Distribution of Building Size')
plt.tight_layout()
plt.show()

# Create a box plot for price_in_rp
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['price_in_rp'])
plt.xlabel('Price (Rp)')
plt.title('Distribution of Price')
plt.tight_layout()
plt.show()

# Create a box plot for Jumlah Kamar
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bedrooms'])
plt.xlabel('Total of Bedrooms')
plt.title('Distribution of Bedrooms')
plt.tight_layout()
plt.show()

# Create a box plot for Jumlah Kamar Mandi
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bathrooms'])
plt.xlabel('Total of Bathrooms')
plt.title('Distribution of Bathrooms')
plt.tight_layout()
plt.show()

# %%
# Keep only Total Bedrooms <= 20
df = df[df['bedrooms'] <= 20]

# Create a box plot for land_size_m2
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['land_size_m2'])
plt.xlabel('Land Size (m2)')
plt.title('Distribution of Land Size')
plt.tight_layout()
plt.show()

# Create a box plot for building_size_m2
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['building_size_m2'])
plt.xlabel('Building Size (m2)')
plt.title('Distribution of Building Size')
plt.tight_layout()
plt.show()

# Create a box plot for price_in_rp
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['price_in_rp'])
plt.xlabel('Price (Rp)')
plt.title('Distribution of Price')
plt.tight_layout()
plt.show()

# Create a box plot for Jumlah Kamar
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bedrooms'])
plt.xlabel('Total of Bedrooms')
plt.title('Distribution of Bedrooms')
plt.tight_layout()
plt.show()

# Create a box plot for Jumlah Kamar Mandi
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bathrooms'])
plt.xlabel('Total of Bathrooms')
plt.title('Distribution of Bathrooms')
plt.tight_layout()
plt.show()

# %%
# Keep only Total Bathrooms <= 17
df = df[df['bathrooms'] <= 17]

# Create a box plot for land_size_m2
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['land_size_m2'])
plt.xlabel('Land Size (m2)')
plt.title('Distribution of Land Size')
plt.tight_layout()
plt.show()

# Create a box plot for building_size_m2
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['building_size_m2'])
plt.xlabel('Building Size (m2)')
plt.title('Distribution of Building Size')
plt.tight_layout()
plt.show()

# Create a box plot for price_in_rp
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['price_in_rp'])
plt.xlabel('Price (Rp)')
plt.title('Distribution of Price')
plt.tight_layout()
plt.show()

# Create a box plot for Jumlah Kamar
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bedrooms'])
plt.xlabel('Total of Bedrooms')
plt.title('Distribution of Bedrooms')
plt.tight_layout()
plt.show()

# Create a box plot for Jumlah Kamar Mandi
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['bathrooms'])
plt.xlabel('Total of Bathrooms')
plt.title('Distribution of Bathrooms')
plt.tight_layout()
plt.show()

# %% [markdown]
# >> This code is used to remove extreme outliers from the dataset by applying upper limits (filters) on key numerical features. Each line keeps only rows that fall below a specified threshold, ensuring the dataset focuses on realistic property values rather than extreme cases:
# >> 1. Price: Properties are limited to ≤ Rp 120 billion, excluding ultra-luxury or erroneous listings.
# 2. Land Size: Capped at ≤ 3,000 m², which removes unusually large plots (e.g., estates or commercial land).
# 3. Building Size: Limited to ≤ 1,600 m², keeping only standard residential and medium-scale buildings.
# 4. Bedrooms: Capped at ≤ 20, excluding unrealistic cases (e.g., 50–99 bedrooms likely representing hotels or boarding houses).
# 5. Bathrooms: Restricted to ≤ 17, again removing abnormal entries with 30–99 bathrooms.
#
# >>**Insight**: By applying these thresholds, the dataset becomes more representative of typical residential properties. This reduces skewness, improves visualization clarity, and ensures statistical models or machine learning algorithms are not distorted by extreme outliers that don’t reflect normal housing market conditions

# %% [markdown]
# # Correlation Heatmap

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.select_dtypes(include=['float64', 'int64']).corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Numerical Variables')
plt.show()

# %% [markdown]
# **Strong Correlations**:
# - Price vs. Building Size (0.76) → The strongest correlation, suggesting that larger building areas significantly drive up property prices.
# - Price vs. Land Size (0.63) → Strong positive correlation, meaning bigger plots of land generally increase property value.
# - Bedrooms vs. Bathrooms (0.78) → Very strong relationship, indicating that properties with more bedrooms almost always have more bathrooms.
# - Maid Bedrooms vs. Maid Bathrooms (0.74) → Strong correlation, which is logical since these features usually come in pairs.
# - Building Size vs. Land Size (0.69) → Large land areas are often associated with larger buildings.
#
# **Moderate Correlations**:
# - Price vs. Bedrooms (0.44) and Bathrooms (0.50) → More rooms typically raise prices, but not as strongly as overall size.
# - Carports vs. Building Size (0.56) → Bigger houses often include more carports.
# - Facilities vs. Condition/Furnishing Score (0.41) → Suggests that better property conditions often align with more facilities, but the relationship is not very strong.
#
# **Weak or No Correlations**:
# - Facilities vs. Price (0.02) → Having more facilities doesn’t directly drive property prices.
# - Condition/Furnishing Score vs. Price (0.01) → Surprisingly almost no relationship, indicating that condition and furnishing alone don’t strongly influence price compared to land/building size.
# - Year Built vs. Price (-0.17) → Very weak negative correlation, suggesting that newer homes aren’t necessarily more expensive, likely due to location and size being more decisive factors.
#
# **Insights**:
# Property prices in this dataset are driven primarily by physical size (land and building area) rather than facilities or furnishing quality. Bedrooms and bathrooms show strong internal correlations but are weaker predictors of price. This means that when building predictive models, land size, building size, and total rooms will likely be the most important features, while facilities and furnishing may have limited predictive power.

# %% [markdown]
# # Scatter Plot

# %%
# Create a scatter plot for price_in_rp vs land_size_m2
plt.figure(figsize=(8, 5))
sns.scatterplot(x='land_size_m2', y='price_in_rp', data=df)
plt.xlabel('Land Size (m2)', fontsize=12)
plt.ylabel('Price (Rp)', fontsize=12)
plt.title('Price vs. Land Size', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# >> **Insight**: This scatter plot illustrates the relationship between land size (m²) and property price (Rp). The plot shows a general upward trend, meaning that larger land sizes tend to be associated with higher prices. However, the points are widely scattered, indicating that land size alone does not fully explain price variation. Many properties with relatively small land sizes still reach high prices, likely due to factors such as location, building size, or additional facilities.

# %%
# Create a scatter plot with regression line for Price vs. Building Size
plt.figure(figsize=(8, 5))
sns.regplot(x='building_size_m2', y='price_in_rp', data=df, scatter_kws={'alpha':0.5})
plt.xlabel('Building Size (m2)', fontsize=12)
plt.ylabel('Price (Rp)', fontsize=12)
plt.title('Price vs. Building Size with Regression Line', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# >> **Insight**: This scatter plot with a regression line shows the relationship between building size (m²) and property price (Rp). The positive slope of the regression line confirms a strong correlation: as building size increases, property prices tend to rise significantly. The data points, while somewhat scattered, generally follow this upward trend, meaning larger homes consistently command higher prices. However, there are noticeable outliers, some smaller buildings priced very high (likely due to prime location or luxury features) and some larger buildings priced lower than expected. Building size is a strong driver of property prices, but it is not the only factor. While the regression line captures the overall positive relationship, the variation and outliers indicate that other elements, such as land size, city location, and facilities—also influence price. This makes building size one of the most reliable predictors for property value, though it should be analyzed in combination with other features for accurate modeling.

# %%
# Create a scatter plot for luas tanah vs. luas bangunan
plt.figure(figsize=(8, 6))
sns.scatterplot(x='land_size_m2', y='building_size_m2', data=df)
plt.title('Scatter Plot of Luas Tanah vs Luas Bangunan')
plt.xlabel('Luas Tanah (m2)')

plt.ylabel('Luas Bangunan (m2)')
plt.show()

# %% [markdown]
# >> **Insight**: This scatter plot shows the relationship between land size (m²) and building size (m²). Overall, there is a clear positive trend: properties with larger land areas generally also have larger buildings. Most data points are clustered at the lower end, with land sizes under 500 m² and building sizes under 400 m², suggesting that the majority of properties in the dataset are small-to-medium residential houses. However, the spread becomes wider as land size increases, with some properties having large plots but relatively modest buildings, and others with proportionally bigger buildings.

# %% [markdown]
# ## Box Plot

# %%
# Create a box plot of price by city
plt.figure(figsize=(12, 6))
sns.boxplot(x='city', y='price_in_rp', data=df)
plt.xlabel('City', fontsize=12)
plt.ylabel('Price (Rp)', fontsize=12)
plt.title('Price Distribution by City', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# >> **Insight**: This box plot shows the distribution of property prices across different cities. Overall, Jakarta Pusat, Jakarta Selatan, and Jakarta Utara stand out with the highest median prices and the widest spread, reflecting both luxury properties and high market variability. This suggesting diverse property types ranging from mid-level to luxury. In particular, Jakarta Pusat shows extreme outliers, indicating the presence of very high-end properties. Meanwhile, cities like Bekasi, Depok, Bogor, and Tangerang have lower and more clustered price distributions, making them relatively more affordable markets.

# %% [markdown]
# # Density Plot

# %%
# Create a 2D density plot (heatmap) for Bedrooms vs. Bathrooms
plt.figure(figsize=(8, 5))
sns.histplot(data=df, x='bedrooms', y='bathrooms', kde=True, cbar=True)
plt.xlabel('Number of Bedrooms', fontsize=12)
plt.ylabel('Number of Bathrooms', fontsize=12)
plt.title('Density Plot of Bedrooms vs. Bathrooms', fontsize=14)
plt.show()

# %% [markdown]
# >> **Insight**: This density plot shows a clear positive relationship between bedrooms and bathrooms: properties with more bedrooms tend to also have more bathrooms. Most listings are concentrated in the 2–4 bedroom and 2–3 bathroom range, highlighting typical mid-sized family homes, while higher-end properties with 10+ bedrooms and bathrooms exist but are far less common.
